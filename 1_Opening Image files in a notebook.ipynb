# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
# this is because Matplotlib uses RGB order of channel
# and open Cv uses BGR order of channel

# %%
#to fix this 
fix_image=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_image)

# %%
img_gray = cv2.imread('DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE) #reading grayscale directly

# %%
img_gray.shape # notice no RGB channel as it is imported as grayscale
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray) # even tho its a gray scale we get some sort of color 
# due to order of channel in open cv

# %%
plt.imshow(img_gray,cmap="gray")

# %% [markdown]
# REsizing image

# %%
fix_imgae.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(fix_imgae,(1200,400)) 
#here 400 corresponds to 1300 and 1200 corresponds to 1950 in open Cv

# %%
plt.imshow(new_img)

# %% [markdown]
# With Ratio

# %%
w_ratio = 0.5 #50 percent of width
h_ratio = 0.5 #50 percent of height

# %%
new_img =cv2.resize(fix_image,(0,0),fix_imgae,w_ratio,h_ratio)

# %%
new_img.shape
# Out:
# (650, 975, 3)

# %%
plt.imshow(new_img)

# %% [markdown]
# Flip images

# %%
new_img = cv2.flip(fix_imgae,-1) # 0 for horzotal 1 for vertical, -1 for both
plt.imshow(new_img)

# %% [markdown]
# Saving files

# %%
cv2.imwrite("new_img.jpg",new_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111)
ax.imshow(fix_image)
